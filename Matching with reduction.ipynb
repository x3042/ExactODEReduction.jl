# %%
using DifferentialEquations
using Plots
using Nemo
using ExactODEReduction
# Out:
# Welcome to Nemo version 0.31.1
#
# Nemo comes with absolutely no warranty whatsoever
#
# polymake version 4.6
# Copyright (c) 1997-2021
# Ewgenij Gawrilow, Michael Joswig, and the polymake team
# Technische Universität Berlin, Germany
# https://polymake.org
#
# This is free software licensed under GPL; see the source for copying conditions.
# There is NO warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
# ┌ Info: Precompiling ExactODEReduction [790186a0-1ec0-11ec-1f13-43a2532b2fa8]
# └ @ Base loading.jl:1423
# WARNING: Method definition (::Type{ExactODEReduction.MyModNumber})(Any) in module ExactODEReduction at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/MyModNumber.jl:24 overwritten at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/MyModNumber.jl:27.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition random_sparse_vector(Tuple, Nemo.FlintRationalField) in module ExactODEReduction at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/sparse.jl:74 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition random_sparse_vector##kw(Any, typeof(ExactODEReduction.random_sparse_vector), Tuple, Nemo.FlintRationalField) in module ExactODEReduction at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/sparse.jl:74 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition random_sparse_vector(Tuple, Nemo.GaloisFmpzField) in module ExactODEReduction at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/sparse.jl:74 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition random_sparse_vector##kw(Any, typeof(ExactODEReduction.random_sparse_vector), Tuple, Nemo.GaloisFmpzField) in module ExactODEReduction at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/sparse.jl:74 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition random_sparse_vector(Tuple, Nemo.CalciumQQBarField) in module ExactODEReduction at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/sparse.jl:74 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition random_sparse_vector##kw(Any, typeof(ExactODEReduction.random_sparse_vector), Tuple, Nemo.CalciumQQBarField) in module ExactODEReduction at /Users/pogudingleb/.julia/dev/ExactODEReduction/src/sparse.jl:74 overwritten on the same line (check for duplicate calls to `include`).
#   ** incremental compilation may be fatally broken for this module **

# %%
# Load the ODE system from the file
fname = "/Users/pogudingleb/.julia/dev/ExactODEReduction/examples/BIOMD0000000407.ode"
(ode, ics) = ExactODEReduction.load_ODE(fname, true)
@info "Loaded system" ode
@show ics
# Out:
# ics = Dict{Any, Any}("XIAP" => 7.83371, "IKK" => 0.64, "TNF_TNFR_TRADD" => 0.0, "pCasp8" => 3.2, "FLIP_mRNA" => 0.000139056, "TNFR_E" => 0.005, "TNFRC2_pCasp8_pCasp8" => 0.0, "XIAP_mRNA" => 0.000219646, "TNF_E" => 0.2688, "BAR_Casp8" => 0.0, "TNFRC2_FLIP_pCasp8" => 0.0, "TNFR" => 0.00028, "TRAF2" => 0.33056, "TNFRC2" => 0.0, "TNFRC1" => 0.0, "TRADD" => 0.29344, "TNF_TNFR_E" => 0.0, "BAR" => 0.28789, "SINK" => 0.0, "NFkB_N" => 0.000691431, "Casp3" => 0.0, "IkBa_N" => 0.0013839, "IkBa_NFkB_N" => 9.00189e-5, "XIAP_Casp3" => 0.0, "IkBa_mRNA" => 5.31517e-5, "FLIP" => 0.0320472, "PARP" => 1.66667, "TNFRC2_pCasp8" => 0.0, "pCasp3" => 0.8, "RIP" => 0.20256, "TNFRC2_FLIP" => 0.0, "IKKa" => 0.0, "IkBa" => 0.00101518, "TNFRCint2" => 0.0, "A20_mRNA" => 5.56657e-5, "source" => 1.0, "TNFRCint1" => 0.0, "Casp8" => 0.0, "end init" => 0.0, "FADD" => 0.30944, "A20" => 0.104434, "IkBa_NFkB" => 0.0151032, "TNFRC2_FLIP_pCasp8_RIP_TRAF2" => 0.0, "TNFRC2_FLIP_FLIP" => 0.0, "TNFRCint3" => 0.0, "PIkBa" => 0.0, "Casp6" => 0.0, "I" => 1.0, "begin reactions" => 0.0, "NFkB" => 0.000115365, "cPARP" => 0.0, "pCasp6" => 0.064)
# ┌ Info: Loaded system
# │   ode = pCasp3'(t) = 493827//10000000000*I(t)
# TNFRC2_pCasp8'(t) = 1//32*TNFRC2(t)*pCasp8(t)
# pCasp8'(t) = 197531//1000000000*I(t)
# TNF_E'(t) = 660377//10000000000*TNF_TNFR_E(t)
# A20_mRNA'(t) = 94697//2500000000*NFkB_N(t)
# TNFRCint1'(t) = 227//200000*TNFRC1(t)
# FLIP_mRNA'(t) = 333333//10000000000*NFkB_N(t)
# PARP'(t) = -482253//50000000000*I(t)
# NFkB'(t) = 1//625000*I(t) + 104167//1000000*IKKa(t)*IkBa_NFkB(t)
# Casp3'(t) = 1//64*Casp8(t)*pCasp3(t) + 1//1000*XIAP_Casp3(t)
# TNF_TNFR_E'(t) = 953471//100000000*TNFR_E(t)*TNF_E(t)
# I'(t) = 0
# Casp8'(t) = 1//1000*BAR_Casp8(t) + 1//640*Casp6(t)*pCasp8(t) + 3//10*TNFRC2_FLIP_pCasp8(t) + 9//20*TNFRC2_pCasp8_pCasp8(t)
# PIkBa'(t) = 104167//1000000*IKKa(t)*IkBa_NFkB(t)
# source'(t) = 0
# IKKa'(t) = 375//4*IKK(t)*TNFRC1(t) + 1//32*IKK(t)*TNFRC2_FLIP_pCasp8_RIP_TRAF2(t)
# TNFR_E'(t) = 1//1000*TNFR(t) + 660377//10000000000*TNF_TNFR_E(t)
# BAR_Casp8'(t) = 520833//1000000*BAR(t)*Casp8(t)
# TNFRC2_FLIP'(t) = 5//16*FLIP(t)*TNFRC2(t)
# BAR'(t) = 1//1000*BAR_Casp8(t) + 166603//100000000000*I(t)
# TNFRCint3'(t) = 59267//2500000*FADD(t)*TNFRCint2(t)
# TNFRCint2'(t) = 227//200000*TNFRCint1(t)
# TNFRC2_FLIP_pCasp8'(t) = 5//16*FLIP(t)*TNFRC2_pCasp8(t) + 5//16*TNFRC2_FLIP(t)*pCasp8(t)
# XIAP_Casp3'(t) = 5//8*Casp3(t)*XIAP(t)
# IkBa_NFkB'(t) = 5//4*IkBa(t)*NFkB(t) + 30303//2000000*IkBa_NFkB_N(t)
# IkBa_mRNA'(t) = 30303//1000000000*NFkB_N(t)
# TRADD'(t) = 917//31250000*I(t)
# TNFRC2_FLIP_pCasp8_RIP_TRAF2'(t) = 488281//50000000*RIP(t)*TNFRC2_FLIP_pCasp8(t)*TRAF2(t)
# TNFRC2'(t) = 3//10*TNFRC2_FLIP_pCasp8(t) + 9//20*TNFRC2_pCasp8_pCasp8(t) + 227//2000*TNFRCint3(t)
# TNFRC2_FLIP_FLIP'(t) = 5//16*FLIP(t)*TNFRC2_FLIP(t)
# XIAP'(t) = 24133//31250000*I(t) + 21//20000*XIAP_Casp3(t) + 506061//10000000*XIAP_mRNA(t)
# A20'(t) = 30303//2000000*A20_mRNA(t) + 3//312500*I(t)
# TNFR'(t) = 7//25000000*source(t)
# TNFRC2_pCasp8_pCasp8'(t) = 1//32*TNFRC2_pCasp8(t)*pCasp8(t)
# IkBa_N'(t) = 1//200*IkBa(t)
# pCasp6'(t) = 197531//50000000000*I(t)
# IKK'(t) = 1//15625*I(t) + 1//10*IKKa(t)
# FLIP'(t) = 687273//100000000*FLIP_mRNA(t) + 112451//50000000000*I(t)
# IkBa'(t) = 32197//12500000*IkBa_N(t) + 606061//10000000*IkBa_mRNA(t)
# RIP'(t) = 633//31250000*I(t) + 227//200000*TNFRCint1(t)
# XIAP_mRNA'(t) = 333333//10000000000*NFkB_N(t)
# TRAF2'(t) = 1//160*A20(t)*TNFRC1(t) + 1033//31250000*I(t) + 227//200000*TNFRCint1(t)
# NFkB_N'(t) = 1//80*NFkB(t)
# TNFRC1'(t) = 488281//5000000*RIP(t)*TNF_TNFR_TRADD(t)*TRAF2(t)
# TNF_TNFR_TRADD'(t) = 1//160*A20(t)*TNFRC1(t) + 427827//100000000*TNF_TNFR_E(t)*TRADD(t)
# IkBa_NFkB_N'(t) = 3587//2500*IkBa_N(t)*NFkB_N(t)
# Casp6'(t) = 3//320*Casp3(t)*pCasp6(t)
# FADD'(t) = 967//31250000*I(t)
# SINK'(t) = -235249//500000000*A20_mRNA(t) - 36169//625000000*BAR_Casp8(t) - 36169//625000000*Casp3(t) - 36169//625000000*Casp6(t) - 36169//625000000*Casp8(t) - 10359//62500000*FLIP_mRNA(t) + 482253//50000000000*I(t) - 1//10000*IKKa(t) - 77011//50000000*IkBa(t) - 1//10000*IkBa_N(t) - 1//10000*IkBa_NFkB(t) - 1//10000*IkBa_NFkB_N(t) - 394201//1000000000*IkBa_mRNA(t) - 1//10000*NFkB_N(t) - 36169//6250000000*PARP(t) - 115517//10000000*PIkBa(t) - 7//125000*TNFRC1(t) - 7//125000*TNFRC2(t) - 7//125000*TNFRC2_FLIP(t) - 7//125000*TNFRC2_FLIP_FLIP(t) - 7//125000*TNFRC2_FLIP_pCasp8(t) - 7//125000*TNFRC2_FLIP_pCasp8_RIP_TRAF2(t) - 7//125000*TNFRC2_pCasp8(t) - 7//125000*TNFRC2_pCasp8_pCasp8(t) - 7//125000*TNFR_E(t) - 7//125000*TNF_TNFR_E(t) - 147//6250*TNF_TNFR_TRADD(t) - 36169//625000000*XIAP_Casp3(t) - 104931//1000000000*XIAP_mRNA(t) - 36169//6250000000*cPARP(t)
# cPARP'(t) = 3//16*Casp3(t)*PARP(t)
#
# └ @ Main In[2]:4
# Dict{Any, Any} with 52 entries:
#   "XIAP"                 => 7.83371
#   "IKK"                  => 0.64
#   "TNF_TNFR_TRADD"       => 0.0
#   "pCasp8"               => 3.2
#   "FLIP_mRNA"            => 0.000139056
#   "TNFR_E"               => 0.005
#   "TNFRC2_pCasp8_pCasp8" => 0.0
#   "XIAP_mRNA"            => 0.000219646
#   "TNF_E"                => 0.2688
#   "BAR_Casp8"            => 0.0
#   "TNFRC2_FLIP_pCasp8"   => 0.0
#   "TNFR"                 => 0.00028
#   "TRAF2"                => 0.33056
#   "TNFRC2"               => 0.0
#   "TNFRC1"               => 0.0
#   "TRADD"                => 0.29344
#   "TNF_TNFR_E"           => 0.0
#   "BAR"                  => 0.28789
#   "SINK"                 => 0.0
#   "NFkB_N"               => 0.000691431
#   "Casp3"                => 0.0
#   "IkBa_N"               => 0.0013839
#   "IkBa_NFkB_N"          => 9.00189e-5
#   "XIAP_Casp3"           => 0.0
#   "IkBa_mRNA"            => 5.31517e-5
#   ⋮                      => ⋮

# %%
# Call find_reductions providing the loaded system 
# (might take some time)
reductions = ExactODEReduction.find_reductions(ode)
@info "Found reductions" reductions

# Reduction referred to in the paper
reduction = reductions[8]
@info "New system" reduction[:new_system]
@info "New variables" reduction[:new_vars]
#=
    reduction[:new_vars] = [
    y1=    k6/k1*A20 - k5/k3*FLIP,
    y2=    k6*A20_mRNA - k5*IkBa_mRNA,
    ...
    ]
    
    reduction[:new_system] = [
    y1'=   y2 + k2k6/k1 - k4k5/k3,
    y2'=   0,
    ...
    ]
=#
# Out:
# [ Info: constructed a set of 35 matrices 50×50 from the system Jacobian
# [ Info: Called invariant_subspace_global on 35 matrices of shape (50, 50)
# [ Info: found [34]-dim subspaces in ambient 50-dim
# [ Info: Calling myself recursively in restricted subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (34, 34)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# ┌ Warning: inclusion check failed..
# └ @ ExactODEReduction ~/.julia/dev/ExactODEReduction/src/basis.jl:198
# [ Info: new reduction modulo, 4611686014132420667
# ┌ Warning: inclusion check failed..
# └ @ ExactODEReduction ~/.julia/dev/ExactODEReduction/src/basis.jl:198
# [ Info: new reduction modulo, 21267647892944573271954437909048725051
# [ Info: generated a basis for Algebra of dimension 699
# [ Info: Computing the radical..
# [ Info: computed the radical of dimension 295
# [ Info: Found radical of size 295
# [ Info: Radical is nontrivial, computing the general kernel of radical
# [ Info: [7]-dimensional subspaces found
# [ Info: found [7]-dim subspaces in ambient 34-dim
# [ Info: Calling myself recursively in restricted subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (7, 7)
# [ Info: found [1, 2, 3, 4, 5, 6]-dim subspaces in ambient 7-dim
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (27, 27)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# ┌ Warning: inclusion check failed..
# └ @ ExactODEReduction ~/.julia/dev/ExactODEReduction/src/basis.jl:198
# [ Info: new reduction modulo, 4611686014132420667
# [ Info: generated a basis for Algebra of dimension 554
# [ Info: Computing the radical..
# [ Info: computed the radical of dimension 150
# [ Info: Found radical of size 150
# [ Info: Radical is nontrivial, computing the general kernel of radical
# [ Info: [3]-dimensional subspaces found
# [ Info: found [3]-dim subspaces in ambient 27-dim
# [ Info: Calling myself recursively in restricted subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (3, 3)
# [ Info: found [1, 2]-dim subspaces in ambient 3-dim
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (24, 24)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 489
# [ Info: Computing the radical..
# [ Info: computed the radical of dimension 85
# [ Info: Found radical of size 85
# [ Info: Radical is nontrivial, computing the general kernel of radical
# [ Info: [1]-dimensional subspaces found
# [ Info: found [1]-dim subspaces in ambient 24-dim
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (23, 23)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 466
# [ Info: Computing the radical..
# [ Info: computed the radical of dimension 62
# [ Info: Found radical of size 62
# [ Info: Radical is nontrivial, computing the general kernel of radical
# [ Info: [2]-dimensional subspaces found
# [ Info: found [2]-dim subspaces in ambient 23-dim
# [ Info: Calling myself recursively in restricted subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (2, 2)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 4
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (21, 21)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 420
# [ Info: Computing the radical..
# [ Info: computed the radical of dimension 20
# [ Info: Found radical of size 20
# [ Info: Radical is nontrivial, computing the general kernel of radical
# [ Info: [1]-dimensional subspaces found
# [ Info: found [1]-dim subspaces in ambient 21-dim
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (20, 20)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 400
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (16, 16)
# [ Info: found [11]-dim subspaces in ambient 16-dim
# [ Info: Calling myself recursively in restricted subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (11, 11)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 77
# [ Info: Computing the radical..
# [ Info: computed the radical of dimension 28
# [ Info: Found radical of size 28
# [ Info: Radical is nontrivial, computing the general kernel of radical
# [ Info: [4]-dimensional subspaces found
# [ Info: found [4]-dim subspaces in ambient 11-dim
# [ Info: Calling myself recursively in restricted subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (4, 4)
# [ Info: found [1, 2, 3]-dim subspaces in ambient 4-dim
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (7, 7)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 49
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (5, 5)
# [ Info: found [1]-dim subspaces in ambient 5-dim
# [ Info: Calling myself recursively in complemented subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (4, 4)
# [ Info: found [1]-dim subspaces in ambient 4-dim
# [ Info: Calling myself recursively in complemented subspace
# ..............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# [ Info: Called invariant_subspace_global on 35 matrices of shape (3, 3)
# [ Info: found [2]-dim subspaces in ambient 3-dim
# [ Info: Calling myself recursively in restricted subspace
# [ Info: Called invariant_subspace_global on 35 matrices of shape (2, 2)
# [ Info: generating a basis for Algebra using find_basis_1_β
# [ Info: new reduction modulo, 2147483647
# [ Info: generated a basis for Algebra of dimension 1
# [ Info: Computing the radical..
# [ Info: Found radical of size 1
# [ Info: Radical is nontrivial, computing the general kernel of radical
# [ Info: [1]-dimensional subspaces found
# [ Info: found [1]-dim subspaces in ambient 2-dim
# ┌ Info: Found reductions
# │   reductions =
# │    23-element Vector{Dict{Symbol, Vector{Any}}}:
# │     Dict(:new_system => [0], :new_vars => [A20_mRNA - 189394//151515*IkBa_mRNA])
# │     Dict(:new_system => [0, 0], :new_vars => [A20_mRNA - 189394//151515*IkBa_mRNA, FADD - 30944//197531*pCasp8])
# │     Dict(:new_system => [0, 0, 0], :new_vars => [A20_mRNA - 189394//151515*IkBa_mRNA, FADD - 30944//197531*pCasp8, FLIP_mRNA - 11//10*IkBa_mRNA])
# │     Dict(:new_system => [0, 0, 0, 0], :new_vars => [A20_mRNA - 189394//151515*IkBa_mRNA, FADD - 30944//197531*pCasp8, FLIP_mRNA - 11//10*IkBa_mRNA, I])
# │     Dict(:new_system => [0, 0, 0, 0, 0], :new_vars => [A20_mRNA - 189394//151515*IkBa_mRNA, FADD - 30944//197531*pCasp8, FLIP_mRNA - 11//10*IkBa_mRNA, I, RIP - TNFRCint2 - 20256//197531*pCasp8])
# │     ⋮
# │     Dict(:new_system => [30303//2000000*y2 + 3//312500*y11, 94697//2500000000*y20, 1//1000*y4 + 166603//100000000000*y11, 520833//1000000*y3*y7, 1//64*y7*y42 + 1//1000*y40, 3//320*y5*y43, 1//1000*y4 + 1//640*y6*y44 + 3//10*y26 + 9//20*y29, 967//31250000*y11, 687273//100000000*y10 + 112451//50000000000*y11, 333333//10000000000*y20  …  1//160*y1*y23 + 427827//100000000*y35*y37, 917//31250000*y11, 1//160*y1*y23 + 1033//31250000*y11 + 227//200000*y30, 24133//31250000*y11 + 21//20000*y40 + 506061//10000000*y41, 5//8*y5*y39, 333333//10000000000*y20, 493827//10000000000*y11, 197531//50000000000*y11, 197531//1000000000*y11, 0], :new_vars => [A20, A20_mRNA, BAR, BAR_Casp8, Casp3, Casp6, Casp8, FADD, FLIP, FLIP_mRNA  …  TNF_TNFR_TRADD, TRADD, TRAF2, XIAP, XIAP_Casp3, XIAP_mRNA, pCasp3, pCasp6, pCasp8, source])
# │     Dict(:new_system => [30303//2000000*y2 + 3//312500*y11, 94697//2500000000*y20, 1//1000*y4 + 166603//100000000000*y11, 520833//1000000*y3*y7, 1//64*y7*y43 + 1//1000*y41, 3//320*y5*y44, 1//1000*y4 + 1//640*y6*y45 + 3//10*y27 + 9//20*y30, 967//31250000*y11, 687273//100000000*y10 + 112451//50000000000*y11, 333333//10000000000*y20  …  1//160*y1*y24 + 427827//100000000*y36*y38, 917//31250000*y11, 1//160*y1*y24 + 1033//31250000*y11 + 227//200000*y31, 24133//31250000*y11 + 21//20000*y41 + 506061//10000000*y42, 5//8*y5*y40, 333333//10000000000*y20, 493827//10000000000*y11, 197531//50000000000*y11, 197531//1000000000*y11, 0], :new_vars => [A20, A20_mRNA, BAR, BAR_Casp8, Casp3, Casp6, Casp8, FADD, FLIP, FLIP_mRNA  …  TNF_TNFR_TRADD, TRADD, TRAF2, XIAP, XIAP_Casp3, XIAP_mRNA, pCasp3, pCasp6, pCasp8, source])
# │     Dict(:new_system => [30303//2000000*y2 + 3//312500*y11, 94697//2500000000*y20, 1//1000*y4 + 166603//100000000000*y11, 520833//1000000*y3*y7, 1//64*y7*y44 + 1//1000*y42, 3//320*y5*y45, 1//1000*y4 + 1//640*y6*y46 + 3//10*y28 + 9//20*y31, 967//31250000*y11, 687273//100000000*y10 + 112451//50000000000*y11, 333333//10000000000*y20  …  1//160*y1*y25 + 427827//100000000*y37*y39, 917//31250000*y11, 1//160*y1*y25 + 1033//31250000*y11 + 227//200000*y32, 24133//31250000*y11 + 21//20000*y42 + 506061//10000000*y43, 5//8*y5*y41, 333333//10000000000*y20, 493827//10000000000*y11, 197531//50000000000*y11, 197531//1000000000*y11, 0], :new_vars => [A20, A20_mRNA, BAR, BAR_Casp8, Casp3, Casp6, Casp8, FADD, FLIP, FLIP_mRNA  …  TNF_TNFR_TRADD, TRADD, TRAF2, XIAP, XIAP_Casp3, XIAP_mRNA, pCasp3, pCasp6, pCasp8, source])
# │     Dict(:new_system => [30303//2000000*y2 + 3//312500*y11, 94697//2500000000*y20, 1//1000*y4 + 166603//100000000000*y11, 520833//1000000*y3*y7, 1//64*y7*y45 + 1//1000*y43, 3//320*y5*y46, 1//1000*y4 + 1//640*y6*y47 + 3//10*y29 + 9//20*y32, 967//31250000*y11, 687273//100000000*y10 + 112451//50000000000*y11, 333333//10000000000*y20  …  1//160*y1*y25 + 427827//100000000*y38*y40, 917//31250000*y11, 1//160*y1*y25 + 1033//31250000*y11 + 227//200000*y33, 24133//31250000*y11 + 21//20000*y43 + 506061//10000000*y44, 5//8*y5*y42, 333333//10000000000*y20, 493827//10000000000*y11, 197531//50000000000*y11, 197531//1000000000*y11, 0], :new_vars => [A20, A20_mRNA, BAR, BAR_Casp8, Casp3, Casp6, Casp8, FADD, FLIP, FLIP_mRNA  …  TNF_TNFR_TRADD, TRADD, TRAF2, XIAP, XIAP_Casp3, XIAP_mRNA, pCasp3, pCasp6, pCasp8, source])
# └     Dict(:new_system => [30303//2000000*y2 + 3//312500*y11, 94697//2500000000*y20, 1//1000*y4 + 166603//100000000000*y11, 520833//1000000*y3*y7, 1//64*y7*y46 + 1//1000*y44, 3//320*y5*y47, 1//1000*y4 + 1//640*y6*y48 + 3//10*y30 + 9//20*y33, 967//31250000*y11, 687273//100000000*y10 + 112451//50000000000*y11, 333333//10000000000*y20  …  1//160*y1*y26 + 427827//100000000*y39*y41, 917//31250000*y11, 1//160*y1*y26 + 1033//31250000*y11 + 227//200000*y34, 24133//31250000*y11 + 21//20000*y44 + 506061//10000000*y45, 5//8*y5*y43, 333333//10000000000*y20, 493827//10000000000*y11, 197531//50000000000*y11, 197531//1000000000*y11, 0], :new_vars => [A20, A20_mRNA, BAR, BAR_Casp8, Casp3, Casp6, Casp8, FADD, FLIP, FLIP_mRNA  …  TNF_TNFR_TRADD, TRADD, TRAF2, XIAP, XIAP_Casp3, XIAP_mRNA, pCasp3, pCasp6, pCasp8, source])
# ┌ Info: New system
# │   reduction[:new_system] =
# │    8-element Vector{Any}:
# │     30303//2000000*y2 - 94697//5500000*y4 + 7495234853//1890000750000000*y5
# │     0
# │     0
# │     0
# │     0
# │     0
# │     0
# └     0
# ┌ Info: New variables
# │   reduction[:new_vars] =
# │    8-element Vector{Any}:
# │     A20 - 18939400//7560003*FLIP
# │     A20_mRNA - 189394//151515*IkBa_mRNA
# │     FADD - 30944//197531*pCasp8
# │     FLIP_mRNA - 11//10*IkBa_mRNA
# │     I
# │     RIP - TNFRCint2 - 20256//197531*pCasp8
# │     TRADD - 29344//197531*pCasp8
# └     source

# %%
Float64(x::Nemo.fmpq) = Float64(numerator(x)) / Float64(denominator(x))

function evaluate_float(poly, point)
    result = 0.
    for (c, m) in zip(Nemo.coefficients(poly), Nemo.exponent_vectors(poly))
        result += Float64(c) * sum(point .^ m)    
    end
    return result
end

# the system to be solved
function f!(du, u, p, t)
    for i in eachindex(du)
        du[i] = evaluate_float(p[i], u)
    end
    nothing
end
# Out:
# f! (generic function with 1 method)

# %%
# species present in the selected reduction
interesting_species = [
    ExactODEReduction.A20,
    ExactODEReduction.A20_mRNA,
    ExactODEReduction.FLIP,
    ExactODEReduction.IkBa_mRNA,
    ExactODEReduction.NFkB,
    ExactODEReduction.Casp3
]

# Solve the original system

xs = ode.x_vars; n = length(xs)
@show n
eqs = [ode.x_equations[xs[i]] for i in 1:n]
var2idx = Dict((x => i for (i, x) in enumerate(xs)))

# initial conds.
# I assume initial conditions do not matter much
# for checking the consistency (?)
u0 = [ics["$x"] for x in xs]

start, stop = 0.0, 20.0
tspan = (start, stop)
p = eqs

prob = ODEProblem(f!, u0, tspan, p, dense=true)
sol = DifferentialEquations.solve(prob)

# sol - solution of the original system,
# For example, the solution for A20
@show sol[var2idx[ExactODEReduction.A20], :]
# Out:
# n = 50
# sol[var2idx[ExactODEReduction.A20], :] = [0.104434, 0.10443469626075172, 0.10444165886827028, 0.10451128494359177, 0.10520754571039274, 0.11217015473707789, 0.14136852492754542, 0.19892397199539222, 0.2789699664486859, 0.3803757636550345, 0.5060197696355704, 0.6553709357434842, 0.8282960000249718, 1.0233442965005348, 1.2389663642902402, 1.473355211199931, 1.7247373165901547, 1.9911636843156806, 2.2700340845369857, 2.558122045634369, 2.8536829712362, 3.156793120467927, 3.4694520587300017, 3.800731422691412, 4.186740136587269, 4.76745203095332, 6.085937943986083, 10.2604587051068, 25.532564086744774, 83.71063484995875, 307.8005255591715, 1173.005000032303, 4500.718069019632, 17211.241632987254, 65430.1641368263, 246869.5882142085, 922757.2009290869, 3.4105551814292516e6, 1.2460830672053348e7, 4.501095428154902e7, 1.6066809360278296e8, 5.6734353562973e8, 1.9850803352126942e9, 6.894114988402787e9, 2.379608379692671e10, 8.168422923580426e10, 2.788330011774607e11, 9.468538547614729e11, 3.201732519016677e12, 1.0789062446106838e13, 3.625152924066392e13, 1.215006217952217e14, 4.062302195800835e14, 1.354837635823841e15, 4.508923227470115e15, 1.4979863834132654e16, 4.9696103599873144e16, 1.646710799660995e17, 5.450975388961752e17, 1.8028548074918223e18, 2.680391245695546e18]
# 61-element Vector{Float64}:
#  0.104434
#  0.10443469626075172
#  0.10444165886827028
#  0.10451128494359177
#  0.10520754571039274
#  0.11217015473707789
#  0.14136852492754542
#  0.19892397199539222
#  0.2789699664486859
#  0.3803757636550345
#  0.5060197696355704
#  0.6553709357434842
#  0.8282960000249718
#  ⋮
#  1.0789062446106838e13
#  3.625152924066392e13
#  1.215006217952217e14
#  4.062302195800835e14
#  1.354837635823841e15
#  4.508923227470115e15
#  1.4979863834132654e16
#  4.9696103599873144e16
#  1.646710799660995e17
#  5.450975388961752e17
#  1.8028548074918223e18
#  2.680391245695546e18

# %%
plt = nothing
for (i, s) in enumerate(interesting_species)
    if i == 1
        plt = plot(sol[var2idx[s], :], label=s, xaxis="t", title="From the 50-dim simulation")
    else
        plt = plot!(sol[var2idx[s], :], label=s)
    end
end
plt

# %%
xs_r = gens(parent(first(reduction[:new_system])))
n_r = length(xs_r)
eqs_r = reduction[:new_system]

# new initial conditions, inferred as
# u0_r[i] = evaluate new_var[i] at u0
u0_r = [
    evaluate_float(v, u0)
    for v in reduction[:new_vars]
]
p_r = eqs_r
@show eqs_r
@show u0_r

prob_r = ODEProblem(f!, u0_r, tspan, p_r, dense=true)
sol_r = DifferentialEquations.solve(prob_r)

# y1'(t) = sol_r[1,:]
# y2'(t) = sol_r[2,:]
@show sol_r[1, :]
@show sol_r[2, :]  # this one should be constant
# Out:
# eqs_r = Any[30303//2000000*y2 - 94697//5500000*y4 + 7495234853//1890000750000000*y5, 0, 0, 0, 0, 0, 0, 0]
# u0_r = [-73.73117264455821, -12.25009162409355, 41.132106821916565, -4.899919410870005, 50.0, -5.150337519882957, 41.538926531228014, 50.0]
# sol_r[1, :] = [-73.73117264455821, -76.04075545425258]
# sol_r[2, :] = [-12.25009162409355, -12.25009162409355]
# 2-element Vector{Float64}:
#  -12.25009162409355
#  -12.25009162409355

# %%
plt_r = plot(sol_r[1, :], label=xs_r[1], xaxis="t", title="From the reduction")
plt_r

# %%
### check that the results coincide ?

# sol_c[i] is newvar[i] evaluated at sol

sol_c = []
for i in 1:2
    newvar = reduction[:new_vars][i]
    tseries = []
    for (c, m) in zip(Nemo.coefficients(newvar), Nemo.exponent_vectors(newvar))
        push!(tseries, Float64(c) * sol[findfirst(i -> i == 1, m), :])     
    end
    push!(sol_c, [evaluate_float(newvar, [sol[i, j] for i in 1:n]) for j in 1:length(sol[1, :])])
end

@show sol_c[1]   # inferred y1'
@show sol_c[2];  # inferred y2'
# Out:
# sol_c[1] = [-73.73117264455821, -73.73117273925807, -73.73117368625661, -73.73118315624217, -73.73127785609745, -73.73222485465064, -73.73619618044805, -73.74402438882498, -73.75491153427447, -73.76870378646416, -73.78579258984371, -73.806105652983, -73.82962477477369, -73.85615256374552, -73.88547817453315, -73.91735569223715, -73.95154361521375, -73.98777610884544, -74.02569716932263, -74.06486010579286, -74.10500028471628, -74.14603027190964, -74.18786512320729, -74.23041292024726, -74.27358373416229, -74.31729531139511, -74.36147171426002, -74.4060200771371, -74.45074684179863, -74.49543647257266, -74.54009565245707, -74.58472903988172, -74.62924186838882, -74.67354898581834, -74.71763489385921, -74.76146433220129, -74.804982079193, -74.84812773251906, -74.89089155569673, -74.93327851593494, -74.9752729833126, -75.01691007614136, -75.05824112892151, -75.09934711456299, -75.1402702331543, -75.18104553222656, -75.221923828125, -75.2647705078125, -75.30810546875, -75.376953125, -75.3984375, -75.265625, -75.0, -74.25, -76.0, 26.0, -80.0, -384.0, 1472.0, 4352.0, 3072.0]
# sol_c[2] = [-12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.250091624093542, -12.250091624093542, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.250091624093557, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.25009162409355, -12.250091624093557, -12.250091624093542, -12.250091624093528, -12.25009162409333, -12.250091624093557, -12.25009162409333, -12.25009162407514, -12.250091624104243, -12.250091624329798, -12.250091623864137, -12.250091624911875, -12.2500916197896, -12.250091582536697, -12.250091552734375, -12.250091910362244, -12.250092029571533, -12.25009536743164, -12.250106811523438, -12.250106811523438, -12.25018310546875, -12.250244140625, -12.248046875, -12.24609375, -12.2578125, -12.25, -12.75, -12.75, -16.0, -20.0, -64.0, -128.0, 0.0, 512.0, 4096.0, 0.0, 32768.0, -131072.0, -196608.0]

# %%
plt_r = plot!(sol_c[1, :], label="$(xs_r[1]) inferred")
plt_r
